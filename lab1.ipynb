# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51068/AIML-2025_B16/blob/main/lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
lst1=[1,2,3]
array1 = np.array(lst1)
array1
# Out:
# array([1, 2, 3])

# %%
type(lst1)
# Out:
# list

# %%
type(array1)
# Out:
# numpy.ndarray

# %%
l2=[3,2,1]
a2=np.array(l2)
a2
# Out:
# array([3, 2, 1])

# %%
print("array2 multiplied by array1:",array1*a2)
print("array2 divided by array1:",a2/array1)
print("array2 raised to the power of array1:",a2**array1)
print(f"{a2} raised to the power of {array1}:,{a2**array1}")
# Out:
# array2 multiplied by array1: [3 4 3]
# array2 divided by array1: [3.         1.         0.33333333]
# array2 raised to the power of array1: [3 4 1]
# [3 2 1] raised to the power of [1 2 3]:,[3 4 1]

# %%
people=['ann','brandon','david','chen','emily','farook','gagan',
   'hamish','imran','julio','katherine','lilly']
age=[21,12,45,32,37,18,28,52,5,40,48,15]
weight=[55,35,68,77,70,60,72,69,18,65,82,48]
height=[160,135,165,170,173,168,175,159,105,171,155,158]
import matplotlib.pyplot as plt
plt.scatter(weight,height)
plt.title("relationship between weight and height of patients")
plt.ylabel("height in meters")
plt.xlabel("weight of patients in kgs")
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.title("people's weight in kgs",fontsize=16,fontstyle='italic')
#main plot function 'bar'
plt.bar(x=people,height=weight,width=0.6,color='violet',edgecolor='k',alpha=0.6)
plt.xlabel("people",fontsize=15)
#plt.xticks(fontsize=14,rotation=30)
#plt.yticks(fontsize=14)
plt.ylabel("weight(in kgs)",fontsize=15)
plt.show()

# %%
import numpy as np
plt.figure(figsize=(7,5))
plt.hist(weight,color='green',edgecolor='k',alpha=0.75,bins=5)
plt.title("histogram of patient weight",fontsize=18)
plt.xlabel("weight in kgs",fontsize=15)
plt.show()
